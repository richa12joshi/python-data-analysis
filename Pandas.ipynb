# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/test.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['PassengerId'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: PassengerId, Length: 418, dtype: bool

# %%
df[df['PassengerId'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Pclass'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Sex'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Age'].isna()]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df['Age'].fillna(30)
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    30.0
# 414    39.0
# 415    38.5
# 416    30.0
# 417    30.0
# Name: Age, Length: 418, dtype: float64

# %%
df['Age'].mean()
# Out:
# np.float64(30.272590361445783)

# %%
df['Age'].fillna(df['Age'].mean(),inplace = True)
# Out:
# /tmp/ipykernel_1233/1652017284.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
df[df['Age'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['SibSp'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Parch'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Ticket'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Fare'].isna()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked
# 152   NaN   NaN        S

# %%
df.dropna(subset=['Fare'], inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
df.iloc[152]
# Out:
# PassengerId                                              1045
# Pclass                                                      3
# Name           Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# Sex                                                    female
# Age                                                      36.0
# SibSp                                                       0
# Parch                                                       2
# Ticket                                                 350405
# Fare                                                  12.1833
# Cabin                                                     NaN
# Embarked                                                    S
# Name: 153, dtype: object

# %%
df.iloc[150:155]
# Out:
#      PassengerId  Pclass                                            Name  \
# 150         1042       1           Earnshaw, Mrs. Boulton (Olive Potter)
# 151         1043       3                            Matinoff, Mr. Nicola
# 153         1045       3  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# 154         1046       3                    Asplund, Master. Filip Oscar
# 155         1047       3                            Duquemin, Mr. Joseph
#
#         Sex       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 150  female  23.00000      0      1          11767  83.1583   C54        C
# 151    male  30.27259      0      0         349255   7.8958   NaN        C
# 153  female  36.00000      0      2         350405  12.1833   NaN        S
# 154    male  13.00000      4      2         347077  31.3875   NaN        S
# 155    male  24.00000      0      0  S.O./P.P. 752   7.5500   NaN        S

# %%
df.reset_index(drop = True)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1305       3                            Spector, Mr. Woolf
# 413         1306       1                  Oliva y Ocana, Dona. Fermina
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
df.reset_index(drop = True,  inplace = True)

# %%
df.iloc[150:155]
# Out:
#      PassengerId  Pclass                                            Name  \
# 150         1042       1           Earnshaw, Mrs. Boulton (Olive Potter)
# 151         1043       3                            Matinoff, Mr. Nicola
# 152         1045       3  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# 153         1046       3                    Asplund, Master. Filip Oscar
# 154         1047       3                            Duquemin, Mr. Joseph
#
#         Sex       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 150  female  23.00000      0      1          11767  83.1583   C54        C
# 151    male  30.27259      0      0         349255   7.8958   NaN        C
# 152  female  36.00000      0      2         350405  12.1833   NaN        S
# 153    male  13.00000      4      2         347077  31.3875   NaN        S
# 154    male  24.00000      0      0  S.O./P.P. 752   7.5500   NaN        S

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 411         1304       3                Henriksson, Miss. Jenny Lovisa
# 412         1305       3                            Spector, Mr. Woolf
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# ...

# %%
df.drop('Cabin', axis = 1, inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1305       3                            Spector, Mr. Woolf
# 413         1306       1                  Oliva y Ocana, Dona. Fermina
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df[df['Embarked'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %% [markdown]
# Notes

# %% [markdown]
#  | #  | Topic                                   | Functions / Concepts                 | What You Covered                                       |
# | -- | --------------------------------------- | ------------------------------------ | ------------------------------------------------------ |
# | 42 | **Missing Data Detection**              | `df.isna()`                          | Identify missing (`NaN`) values                        |
# | 43 | **Checking Missing Values in a Column** | `df['Age'].isna()`                   | Find missing values specifically in a column           |
# | 44 | **Missing Age Values**                  | `fillna()`                           | Fill missing Age values                                |
# | 45 | **Fill with a Fixed Value**             | `df['Age'].fillna(30)`               | Replace missing values with a specified value          |
# | 46 | **Fill with Mean**                      | `df['Age'].fillna(df['Age'].mean())` | Replace missing values using the column mean           |
# | 47 | **In-place Missing Value Replacement**  | `inplace=True`                       | Apply `fillna()` directly to the original data         |
# | 48 | **Dropping Missing Rows**               | `dropna()`                           | Remove rows containing missing values                  |
# | 49 | **Selective Row Dropping**              | `subset=`                            | Drop rows based on missing values in a specific column |
# | 50 | **Resetting Index**                     | `reset_index()`                      | Restore a sequential DataFrame index                   |
# | 51 | **Dropping Old Index**                  | `drop=True`                          | Prevent the old index from becoming a new column       |
# | 52 | **Axis-Label Error**                    | `KeyError` / axis label error        | Trying to drop a column/label that doesn't exist       |
